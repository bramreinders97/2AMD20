# %% [markdown]
# Imports

# %%
import pandas as pd
from rdflib import Graph, URIRef, RDF, Literal
from rdflib.namespace import XSD, RDF

# %% [markdown]
# Retrieve DFs

# %%
moves = pd.read_pickle("../Prepared_DFs/moves.pkl")
house_prices = pd.read_pickle("../Prepared_DFs/house_prices.pkl")
house_prices_new = pd.read_pickle("../Prepared_DFs/house_prices_new.pkl")
house_availability = pd.read_pickle("../Prepared_DFs/house_availability.pkl")
population = pd.read_pickle("../Prepared_DFs/population.pkl")

# %%
house_prices_new.head().dtypes
# Out:
# ID                            int64
# RegioS                       object
# Perioden                     object
# Woningen_2                  float64
# GemiddeldeWoningwaarde_4     object
# dtype: object

# %%
def from_table_to_rdf(rdf_graph, df, table_name):

    columns = df.columns.to_list()
    columns.remove('ID')
    
    table_IRI = URIRef(f"{table_name}")

    for _, row in df.iterrows():

        #create <Moves/ID=283955>
        row_IRI = URIRef(f"{table_name}/ID={row['ID']}")
        rdf_graph.add((row_IRI, RDF.type, table_IRI))

        #loop over columns in order to add all of those things
        for col in columns:
            col_IRI = URIRef(f"{table_name}#{col}")
            literal = Literal(row[col])

            rdf_graph.add((row_IRI, col_IRI, literal))

# %%
g = Graph()

from_table_to_rdf(g, moves.head(), "Moves")
from_table_to_rdf(g, house_prices_new.head(), "HousePrices")
from_table_to_rdf(g, house_availability.head(), "HouseAvailability")
from_table_to_rdf(g, population.head(), "Population")

print(g.serialize(format='n3'))
# Out:
# @prefix ns1: <Population#> .
# @prefix ns2: <HouseAvailability#> .
# @prefix ns3: <Moves#> .
# @prefix ns4: <HousePrices#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <HouseAvailability/ID=664> a <HouseAvailability> ;
#     ns2:EigendomOnbekend_6 1.63e+02 ;
#     ns2:EigendomOverigeVerhuurders_5 6.939e+03 ;
#     ns2:EigendomWoningcorporatie_4 2.1785e+04 ;
#     ns2:Koopwoningen_2 5.0834e+04 ;
#     ns2:Perioden "2016JJ00" ;
#     ns2:RegioS "GM0034" ;
#     ns2:StatusVanBewoning "T001235" ;
#     ns2:TotaalHuurwoningen_3 2.8724e+04 ;
#     ns2:TotaleWoningvoorraad_1 7.9721e+04 .
#
# <HouseAvailability/ID=665> a <HouseAvailability> ;
#     ns2:EigendomOnbekend_6 1.61e+02 ;
#     ns2:EigendomOverigeVerhuurders_5 7.261e+03 ;
#     ns2:EigendomWoningcorporatie_4 2.1827e+04 ;
#     ns2:Koopwoningen_2 5.1333e+04 ;
#     ns2:Perioden "2017JJ00" ;
#     ns2:RegioS "GM0034" ;
#     ns2:StatusVanBewoning "T001235" ;
#     ns2:TotaalHuurwoningen_3 2.9088e+04 ;
#     ns2:TotaleWoningvoorraad_1 8.0582e+04 .
#
# <HouseAvailability/ID=666> a <HouseAvailability> ;
#     ns2:EigendomOnbekend_6 2.39e+02 ;
#     ns2:EigendomOverigeVerhuurders_5 8.142e+03 ;
#     ns2:EigendomWoningcorporatie_4 2.1855e+04 ;
#     ns2:Koopwoningen_2 5.2076e+04 ;
#     ns2:Perioden "2018JJ00" ;
#     ns2:RegioS "GM0034" ;
#     ns2:StatusVanBewoning "T001235" ;
#     ns2:TotaalHuurwoningen_3 2.9997e+04 ;
#     ns2:TotaleWoningvoorraad_1 8.2312e+04 .
#
# <HouseAvailability/ID=667> a <HouseAvailability> ;
#     ns2:EigendomOnbekend_6 1.71e+02 ;
#     ns2:EigendomOverigeVerhuurders_5 6.984e+03 ;
#     ns2:EigendomWoningcorporatie_4 2.2978e+04 ;
#     ns2:Koopwoningen_2 5.4028e+04 ;
#     ns2:Perioden "2019JJ00" ;
#     ns2:RegioS "GM0034" ;
#     ns2:StatusVanBewoning "T001235" ;
#     ns2:TotaalHuurwoningen_3 2.9962e+04 ;
#     ns2:TotaleWoningvoorraad_1 8.4161e+04 .
#
# <HouseAvailability/ID=668> a <HouseAvailability> ;
#     ns2:EigendomOnbekend_6 1.76e+02 ;
#     ns2:EigendomOverigeVerhuurders_5 7.561e+03 ;
#     ns2:EigendomWoningcorporatie_4 2.3334e+04 ;
#     ns2:Koopwoningen_2 5.4906e+04 ;
#     ns2:Perioden "2020JJ00" ;
#     ns2:RegioS "GM0034" ;
#     ns2:StatusVanBewoning "T001235" ;
#     ns2:TotaalHuurwoningen_3 3.0895e+04 ;
#     ns2:TotaleWoningvoorraad_1 8.5977e+04 .
#
# <HousePrices/ID=1699> a <HousePrices> ;
#     ns4:GemiddeldeWoningwaarde_4 "     181" ;
#     ns4:Perioden "2016JJ00" ;
#     ns4:RegioS "GM0034" ;
#     ns4:Woningen_2 1.4725e+04 .
#
# <HousePrices/ID=1700> a <HousePrices> ;
#     ns4:GemiddeldeWoningwaarde_4 "     187" ;
#     ns4:Perioden "2017JJ00" ;
#     ns4:RegioS "GM0034" ;
#     ns4:Woningen_2 1.5559e+04 .
#
# <HousePrices/ID=1701> a <HousePrices> ;
#     ns4:GemiddeldeWoningwaarde_4 "     198" ;
#     ns4:Perioden "2018JJ00" ;
#     ns4:RegioS "GM0034" ;
#     ns4:Woningen_2 1.6057e+04 .
#
# <HousePrices/ID=1702> a <HousePrices> ;
#     ns4:GemiddeldeWoningwaarde_4 "     219" ;
#     ns4:Perioden "2019JJ00" ;
#     ns4:RegioS "GM0034" ;
#     ns4:Woningen_2 1.8898e+04 .
#
# <HousePrices/ID=1703> a <HousePrices> ;
#     ns4:GemiddeldeWoningwaarde_4 "     249" ;
#     ns4:Perioden "2020JJ00" ;
#     ns4:RegioS "GM0034" ;
#     ns4:Woningen_2 2.1743e+04 .
#
# <Moves/ID=283955> a <Moves> ;
#     ns3:Perioden "2016JJ00" ;
#     ns3:RegioVanVertrek "GM0034" ;
#     ns3:RegioVanVestiging "GM1680" ;
#     ns3:TussenGemeentenVerhuisdePersonen_1 0e+00 .
#
# <Moves/ID=283956> a <Moves> ;
#     ns3:Perioden "2017JJ00" ;
#     ns3:RegioVanVertrek "GM0034" ;
#     ns3:RegioVanVestiging "GM1680" ;
#     ns3:TussenGemeentenVerhuisdePersonen_1 2e+00 .
#
# <Moves/ID=283957> a <Moves> ;
#     ns3:Perioden "2018JJ00" ;
#     ns3:RegioVanVertrek "GM0034" ;
#     ns3:RegioVanVestiging "GM1680" ;
#     ns3:TussenGemeentenVerhuisdePersonen_1 7e+00 .
#
# <Moves/ID=283958> a <Moves> ;
#     ns3:Perioden "2019JJ00" ;
#     ns3:RegioVanVertrek "GM0034" ;
#     ns3:RegioVanVestiging "GM1680" ;
#     ns3:TussenGemeentenVerhuisdePersonen_1 6e+00 .
#
# <Moves/ID=283959> a <Moves> ;
#     ns3:Perioden "2020JJ00" ;
#     ns3:RegioVanVertrek "GM0034" ;
#     ns3:RegioVanVestiging "GM1680" ;
#     ns3:TussenGemeentenVerhuisdePersonen_1 6e+00 .
#
# <Population/ID=4753> a <Population> ;
#     ns1:BevolkingOp1Januari_1 1.98145e+05 ;
#     ns1:BevolkingOp31December_20 2.00914e+05 ;
#     ns1:Bevolkingsdichtheid_2 "    1533" ;
#     ns1:EmigratieInclusiefAdministratieveC_14 1.623e+03 ;
#     ns1:Geboorteoverschot_7 1.379e+03 ;
#     ns1:Geslacht "T001038" ;
#     ns1:Immigratie_10 2.339e+03 ;
#     ns1:LevendGeborenKinderenRelatief_4 "    11.8" ;
#     ns1:LevendGeborenKinderen_3 2.359e+03 ;
#     ns1:NaarAndereGemeente_16 7.411e+03 ;
#     ns1:OverledenenRelatief_6 "     4.9" ;
#     ns1:Overledenen_5 9.8e+02 ;
#     ns1:Perioden "2016JJ00" ;
#     ns1:RegioS "GM0034" ;
#     ns1:SaldoAdministratieveCorrecties_15 -9.2e+01 ;
#     ns1:TotaalVertrekInclusiefCoRelatief_13 "    45.3" ;
#     ns1:TotaalVertrekInclusiefCorrecties_12 9.034e+03 ;
#     ns1:TotaalVestigingRelatief_9 "    52.3" ;
#     ns1:TotaalVestiging_8 1.0426e+04 ;
#     ns1:TotaleGroeiRelatief_19 "    14.0" ;
#     ns1:TotaleGroei_18 2.769e+03 ;
#     ns1:UitAndereGemeente_11 8.087e+03 ;
#     ns1:VestigingsoverschotInclusiefCorrecties_17 1.392e+03 .
#
# <Population/ID=4754> a <Population> ;
#     ns1:BevolkingOp1Januari_1 2.00914e+05 ;
#     ns1:BevolkingOp31December_20 2.0399e+05 ;
#     ns1:Bevolkingsdichtheid_2 "    1555" ;
#     ns1:EmigratieInclusiefAdministratieveC_14 1.511e+03 ;
#     ns1:Geboorteoverschot_7 1.357e+03 ;
#     ns1:Geslacht "T001038" ;
#     ns1:Immigratie_10 2.165e+03 ;
#     ns1:LevendGeborenKinderenRelatief_4 "    11.4" ;
#     ns1:LevendGeborenKinderen_3 2.299e+03 ;
#     ns1:NaarAndereGemeente_16 7.564e+03 ;
#     ns1:OverledenenRelatief_6 "     4.7" ;
#     ns1:Overledenen_5 9.42e+02 ;
#     ns1:Perioden "2017JJ00" ;
#     ns1:RegioS "GM0034" ;
#     ns1:SaldoAdministratieveCorrecties_15 -6.4e+01 ;
#     ns1:TotaalVertrekInclusiefCoRelatief_13 "    44.8" ;
#     ns1:TotaalVertrekInclusiefCorrecties_12 9.075e+03 ;
#     ns1:TotaalVestigingRelatief_9 "    53.4" ;
#     ns1:TotaalVestiging_8 1.0805e+04 ;
#     ns1:TotaleGroeiRelatief_19 "    15.3" ;
#     ns1:TotaleGroei_18 3.076e+03 ;
#     ns1:UitAndereGemeente_11 8.64e+03 ;
#     ns1:VestigingsoverschotInclusiefCorrecties_17 1.73e+03 .
#
# <Population/ID=4755> a <Population> ;
#     ns1:BevolkingOp1Januari_1 2.0399e+05 ;
#     ns1:BevolkingOp31December_20 2.07904e+05 ;
#     ns1:Bevolkingsdichtheid_2 "    1579" ;
#     ns1:EmigratieInclusiefAdministratieveC_14 1.495e+03 ;
#     ns1:Geboorteoverschot_7 1.346e+03 ;
#     ns1:Geslacht "T001038" ;
#     ns1:Immigratie_10 2.469e+03 ;
#     ns1:LevendGeborenKinderenRelatief_4 "    11.5" ;
#     ns1:LevendGeborenKinderen_3 2.362e+03 ;
#     ns1:NaarAndereGemeente_16 7.489e+03 ;
#     ns1:OverledenenRelatief_6 "     4.9" ;
#     ns1:Overledenen_5 1.016e+03 ;
#     ns1:Perioden "2018JJ00" ;
#     ns1:RegioS "GM0034" ;
#     ns1:SaldoAdministratieveCorrecties_15 3.1e+01 ;
#     ns1:TotaalVertrekInclusiefCoRelatief_13 "    43.6" ;
#     ns1:TotaalVertrekInclusiefCorrecties_12 8.984e+03 ;
#     ns1:TotaalVestigingRelatief_9 "    56.2" ;
#     ns1:TotaalVestiging_8 1.1564e+04 ;
#     ns1:TotaleGroeiRelatief_19 "    19.2" ;
#     ns1:TotaleGroei_18 3.914e+03 ;
#     ns1:UitAndereGemeente_11 9.095e+03 ;
#     ns1:VestigingsoverschotInclusiefCorrecties_17 2.58e+03 .
#
# <Population/ID=4756> a <Population> ;
#     ns1:BevolkingOp1Januari_1 2.07904e+05 ;
#     ns1:BevolkingOp31December_20 2.11893e+05 ;
#     ns1:Bevolkingsdichtheid_2 "    1609" ;
#     ns1:EmigratieInclusiefAdministratieveC_14 1.564e+03 ;
#     ns1:Geboorteoverschot_7 1.533e+03 ;
#     ns1:Geslacht "T001038" ;
#     ns1:Immigratie_10 2.685e+03 ;
#     ns1:LevendGeborenKinderenRelatief_4 "    12.2" ;
#     ns1:LevendGeborenKinderen_3 2.558e+03 ;
#     ns1:NaarAndereGemeente_16 8.169e+03 ;
#     ns1:OverledenenRelatief_6 "     4.9" ;
#     ns1:Overledenen_5 1.025e+03 ;
#     ns1:Perioden "2019JJ00" ;
#     ns1:RegioS "GM0034" ;
#     ns1:SaldoAdministratieveCorrecties_15 -4.6e+01 ;
#     ns1:TotaalVertrekInclusiefCoRelatief_13 "    46.4" ;
#     ns1:TotaalVertrekInclusiefCorrecties_12 9.733e+03 ;
#     ns1:TotaalVestigingRelatief_9 "    58.2" ;
#     ns1:TotaalVestiging_8 1.2209e+04 ;
#     ns1:TotaleGroeiRelatief_19 "    19.2" ;
#     ns1:TotaleGroei_18 3.989e+03 ;
#     ns1:UitAndereGemeente_11 9.524e+03 ;
#     ns1:VestigingsoverschotInclusiefCorrecties_17 2.476e+03 .
#
# <Population/ID=4757> a <Population> ;
#     ns1:BevolkingOp1Januari_1 2.11893e+05 ;
#     ns1:BevolkingOp31December_20 2.14715e+05 ;
#     ns1:Bevolkingsdichtheid_2 "    1640" ;
#     ns1:EmigratieInclusiefAdministratieveC_14 1.407e+03 ;
#     ns1:Geboorteoverschot_7 1.419e+03 ;
#     ns1:Geslacht "T001038" ;
#     ns1:Immigratie_10 2.131e+03 ;
#     ns1:LevendGeborenKinderenRelatief_4 "    11.7" ;
#     ns1:LevendGeborenKinderen_3 2.503e+03 ;
#     ns1:NaarAndereGemeente_16 8.941e+03 ;
#     ns1:OverledenenRelatief_6 "     5.1" ;
#     ns1:Overledenen_5 1.084e+03 ;
#     ns1:Perioden "2020JJ00" ;
#     ns1:RegioS "GM0034" ;
#     ns1:SaldoAdministratieveCorrecties_15 -2.1e+01 ;
#     ns1:TotaalVertrekInclusiefCoRelatief_13 "    48.5" ;
#     ns1:TotaalVertrekInclusiefCorrecties_12 1.0348e+04 ;
#     ns1:TotaalVestigingRelatief_9 "    55.1" ;
#     ns1:TotaalVestiging_8 1.1748e+04 ;
#     ns1:TotaleGroeiRelatief_19 "    13.3" ;
#     ns1:TotaleGroei_18 2.822e+03 ;
#     ns1:UitAndereGemeente_11 9.617e+03 ;
#     ns1:VestigingsoverschotInclusiefCorrecties_17 1.4e+03 .

# %%
township = URIRef('http://rdfs.co/juso/Township')
gm0034 = URIRef("http://example.org/gm0034")

"""Ik denk dat we door de verschillende tables moeten loopen en dan triples toevoegen waarbij de gemeentes steeds de subject (eerste ding in de triple) zijn
Zoals bijv hieronder:

GM0034 -> is een -> gemeente (aangegeven door de uri hierboven)
(ik denk eigenlijk dat we voor GM0034 ook online references kunnen vinden naar de wiki oid van de daadwerkelijke gemeente ipv t te doen via http://example.org/gm0034

Door alle tables in triples aan 1 graph toe te voegen heb je dan alle info op 1 plek"""

g = Graph()

g.add((gm0034, RDF.type, township))

# print(g.serialize(format='n3'))
# Out:
# <Graph identifier=Nab0a6b1248f04b9e98c3e710e3b18d49 (<class 'rdflib.graph.Graph'>)>
